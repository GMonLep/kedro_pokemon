# %%
# %load_ext kedro.ipython
# Out:
# [03/31/26 14:59:10] INFO     Using 'C:\Users\W608-PCXX\Desktop\Nueva                                __init__.py:269
#                              carpeta\kedro_pokemon\.venv\Lib\site-packages\kedro\framework\project\
#                              rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   __init__.py:64
#                     INFO     Registered line magic '%load_node'                                      __init__.py:66
#                     INFO     Resolved project path as: C:\Users\W608-PCXX\Desktop\Nueva             __init__.py:181
#                              carpeta\kedro_pokemon.
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/31/26 14:59:14] INFO     Kedro is sending anonymous usage data with the sole purpose of improving plugin.py:242
# ...
